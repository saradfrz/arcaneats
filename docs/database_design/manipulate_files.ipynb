# %%
import glob
import pandas as pd

# Get a list of all the csv files in the directory
table_files = glob.glob('table_*.csv')

# Load each csv file into a dataframe
tables = {file_name: pd.read_csv(file_name) for file_name in table_files}

# Print the content of each dataframe
for file_name, table in tables.items():
    print(f"Content of {file_name}:")
    print(table)
    print()
# Out:
# Content of table_basic.csv:
#              column_name data_type
# id                SERIAL        PK
# calories         INTEGER       NaN
# name_en             TEXT       NaN
# name_es             TEXT       NaN
# name_pt             TEXT       NaN
# serving_size     INTEGER       NaN
#
# Content of table_carbo.csv:
#               column_name data_type
# id                 SERIAL        FK
# carbohydrates     INTEGER       NaN
# fiber             INTEGER       NaN
# fructose          INTEGER       NaN
# galactose         INTEGER       NaN
# glucose           INTEGER       NaN
# lactose           INTEGER       NaN
# maltose           INTEGER       NaN
# sucrose           INTEGER       NaN
# sugars            INTEGER       NaN
#
# Content of table_fats.csv:
#                     column_name data_type
# id                       SERIAL        FK
# monounsaturated_fat     INTEGER       NaN
# polyunsaturated_fat     INTEGER       NaN
# saturated_fat           INTEGER       NaN
# total_fat               INTEGER       NaN
# trans_fat               INTEGER       NaN
# cholesterol             INTEGER       NaN
#
# Content of table_minerals.csv:
#            column_name data_type
# id              SERIAL        FK
# calcium        INTEGER       NaN
# copper         INTEGER       NaN
# iron           INTEGER       NaN
# magnesium      INTEGER       NaN
# manganese      INTEGER       NaN
# phosphorus     INTEGER       NaN
# potassium      INTEGER       NaN
# selenium       INTEGER       NaN
# sodium         INTEGER       NaN
# zinc           INTEGER       NaN
#
# Content of table_other.csv:
#                  column_name data_type
# id                    SERIAL        FK
# alcohol              INTEGER       NaN
# ash                  INTEGER       NaN
# caffeine             INTEGER       NaN
# caffeine             INTEGER       NaN
# glucuronolactone     INTEGER       NaN
# inositol             INTEGER       NaN
# taurine              INTEGER       NaN
# theobromine          INTEGER       NaN
# water                INTEGER       NaN
#
# Content of table_protein.csv:
#                column_name data_type
# id                  SERIAL        FK
# alanine            INTEGER       NaN
# arginine           INTEGER       NaN
# aspartic_acid      INTEGER       NaN
# cystine            INTEGER       NaN
# glutamic_acid      INTEGER       NaN
# glycine            INTEGER       NaN
# histidine          INTEGER       NaN
# hydroxyproline     INTEGER       NaN
# isoleucine         INTEGER       NaN
# leucine            INTEGER       NaN
# lysine             INTEGER       NaN
# methionine         INTEGER       NaN
# phenylalanine      INTEGER       NaN
# proline            INTEGER       NaN
# protein            INTEGER       NaN
# serine             INTEGER       NaN
# threonine          INTEGER       NaN
# tryptophan         INTEGER       NaN
# tyrosine           INTEGER       NaN
# valine             INTEGER       NaN
#
# Content of table_vitamins.csv:
#                    column_name data_type
# id                      SERIAL        FK
# carotene_alpha         INTEGER       NaN
# carotene_beta          INTEGER       NaN
# choline                INTEGER       NaN
# cryptoxanthin_beta     INTEGER       NaN
# folate                 INTEGER       NaN
# folic_acid             INTEGER       NaN
# lutein_zeaxanthin      INTEGER       NaN
# lycopene               INTEGER       NaN
# niacin                 INTEGER       NaN
# pantothenic_acid       INTEGER       NaN
# riboflavin             INTEGER       NaN
# thiamin                INTEGER       NaN
# tocopherol_alpha       INTEGER       NaN
# vitamin_a              INTEGER       NaN
# vitamin_a_rae          INTEGER       NaN
# vitamin_b12            INTEGER       NaN
# vitamin_b6             INTEGER       NaN
# vitamin_c              INTEGER       NaN
# vitamin_d              INTEGER       NaN
# vitamin_e              INTEGER       NaN
# vitamin_k              INTEGER       NaN
